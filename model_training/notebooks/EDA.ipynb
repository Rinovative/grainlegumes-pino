# %%
from src import eda, util

# %%
dataset_name = "samples_uniform_var10_N1000"
dataset_df, logs = util.util_data.generate_dataframe(
    dataset_name=dataset_name,
    base_dir="../../data/raw",
    max_cases=10,
    show_progress=True,
)

# %%
toggle = util.util_nb.make_toggle_shortcut(dataset_df, dataset_name)

# Overview
overview_plots = [
    toggle("1-1. Global", eda.eda_spectral_analysis.plot_field_spectra_overview),
    toggle("1-2. Vertical evolution", eda.eda_spectral_analysis.plot_vertical_spectral_lines),
]

# Section in Tabs
sections = [
    util.util_nb.make_dropdown_section(overview_plots, dataset_name),
]

tab_titles = [
    "1. Spectral analysis",
]

# Display EDA Panel
eda_panel = util.util_nb.make_lazy_panel_with_tabs(
    sections,
    tab_titles=tab_titles,
    open_btn_text=f"{dataset_name} Open EDA",
    close_btn_text="Close",
)

display(eda_panel)
