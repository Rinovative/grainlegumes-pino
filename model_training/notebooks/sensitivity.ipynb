# %% [markdown]
# # Archived sensitivity notebook
#
# This file intentionally contains no runnable cells. Sensitivity and capacity analysis is maintained in the evaluation panel, using exact saved-run parameter counts and versioned artifact metadata.
