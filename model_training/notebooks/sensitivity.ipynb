# %% [markdown]
# # Archived sensitivity notebook
#
# This file intentionally contains no runnable workflow. Sensitivity analysis is not a maintained notebook surface. If work resumes, build it against the public `src` APIs and saved-run/artifact contracts.
